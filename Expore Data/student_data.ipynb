# %% [markdown]
# # Student data
# This notebook analyizes pass/fail data for a class

# %%
data =[50,50,97,49,3,53,42,26,74,82,62,37,15,70,27,26,35,48,52,63,64]
print(data*2)
# Out:
# [50, 50, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 26, 35, 48, 52, 63, 64, 50, 50, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 26, 35, 48, 52, 63, 64]

# %%
import numpy as np
grades = np.array(data)
print(grades*2)
# Out:
# [100 100 194  98   6 106  84  52 148 164 124  74  30 140  54  52  70  96
#  104 126 128]
